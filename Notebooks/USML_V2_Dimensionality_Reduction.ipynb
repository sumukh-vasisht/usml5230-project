# %%
''' Install Spotipy package '''

# !pip install spotipy

# %%
''' Mount Google Drive '''

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
''' IMPORTS '''

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.cluster import DBSCAN, KMeans, SpectralClustering, AgglomerativeClustering
from sklearn.neighbors import NearestNeighbors
from collections import Counter
from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture

from sklearn.manifold import TSNE
import plotly.express as px

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

import warnings
warnings.filterwarnings('ignore')

# %%
''' READ DATA '''

data = pd.read_csv('drive/MyDrive/USML/v2/data.csv')
genre_data = pd.read_csv('drive/MyDrive/USML/v2/data_by_genres.csv')
year_data = pd.read_csv('drive/MyDrive/USML/v2/data_by_year.csv')
artist_data = pd.read_csv('drive/MyDrive/USML/v2/data_by_artist.csv')

# %%
''' PRINT DATA '''

data.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# 3       210000   0.309         0  3ftBPsC5vPBKxYSee08FDH          0.000028
# 4       166693   0.193         0  4d6HGyGT8e121BsdKmw9v6          0.000002
#
#    key  liveness  loudness  mode  \
# 0   10     0.665   -20.096     1
# 1    7     0.160   -12.441     1
# 2    3     0.101   -14.850     1
# 3    5     0.381    -9.316     1
# 4    3     0.229   -10.096     1
#
#                                                 name  popularity release_date  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4         1921
# 1                            Clancy Lowered the Boom           5         1921
# 2                                          Gati Bali           5         1921
# 3                                          Danny Boy           3         1921
# 4                        When Irish Eyes Are Smiling           2         1921
#
#    speechiness    tempo
# 0       0.0366   80.954
# 1       0.4150   60.936
# 2       0.0339  110.339
# 3       0.0354  100.109
# 4       0.0380  101.665

# %%
''' PRINT GENRE DATA '''

genre_data.head()
# Out:
#    mode                  genres  acousticness  danceability   duration_ms  \
# 0     1  21st century classical      0.979333      0.162883  1.602977e+05
# 1     1                   432hz      0.494780      0.299333  1.048887e+06
# 2     1                   8-bit      0.762000      0.712000  1.151770e+05
# 3     1                      []      0.651417      0.529093  2.328809e+05
# 4     1              a cappella      0.676557      0.538961  1.906285e+05
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.071317          0.606834  0.361600 -31.514333     0.040567   75.336500
# 1  0.450678          0.477762  0.131000 -16.854000     0.076817  120.285667
# 2  0.818000          0.876000  0.126000  -9.180000     0.047000  133.444000
# 3  0.419146          0.205309  0.218696 -12.288965     0.107872  112.857352
# 4  0.316434          0.003003  0.172254 -12.479387     0.082851  112.110362
#
#     valence  popularity  key
# 0  0.103783   27.833333    6
# 1  0.221750   52.500000    5
# 2  0.975000   48.000000    7
# 3  0.513604   20.859882    7
# 4  0.448249   45.820071    7

# %%
''' PRINT YEAR DATA '''

year_data.head()
# Out:
#    mode  year  acousticness  danceability    duration_ms    energy  \
# 0     1  1921      0.886896      0.418597  260537.166667  0.231815
# 1     1  1922      0.938592      0.482042  165469.746479  0.237815
# 2     1  1923      0.957247      0.577341  177942.362162  0.262406
# 3     1  1924      0.940200      0.549894  191046.707627  0.344347
# 4     1  1925      0.962607      0.573863  184986.924460  0.278594
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.344878  0.205710 -17.048667     0.073662  101.531493  0.379327
# 1          0.434195  0.240720 -19.275282     0.116655  100.884521  0.535549
# 2          0.371733  0.227462 -14.129211     0.093949  114.010730  0.625492
# 3          0.581701  0.235219 -14.231343     0.092089  120.689572  0.663725
# 4          0.418297  0.237668 -14.146414     0.111918  115.521921  0.621929
#
#    popularity  key
# 0    0.653333    2
# 1    0.140845   10
# 2    5.389189    0
# 3    0.661017   10
# 4    2.604317    5

# %%
''' PRINT ARTIST DATA '''

artist_data.head()
# Out:
#    mode  count  acousticness  \
# 0     1      9      0.590111
# 1     1     26      0.862538
# 2     1      7      0.856571
# 3     1     27      0.884926
# 4     1      7      0.510714
#
#                                              artists  danceability  \
# 0                   "Cats" 1981 Original London Cast      0.467222
# 1                          "Cats" 1983 Broadway Cast      0.441731
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.348286
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.425074
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.467143
#
#      duration_ms    energy  instrumentalness  liveness   loudness  \
# 0  250318.555556  0.394003          0.011400  0.290833 -14.448000
# 1  287280.000000  0.406808          0.081158  0.315215 -10.690000
# 2  328920.000000  0.286571          0.024593  0.325786 -15.230714
# 3  262890.962963  0.245770          0.073587  0.275481 -15.639370
# 4  270436.142857  0.488286          0.009400  0.195000 -10.236714
#
#    speechiness       tempo   valence  popularity  key
# 0     0.210389  117.518111  0.389500   38.333333    5
# 1     0.176212  103.044154  0.268865   30.576923    5
# 2     0.118514   77.375857  0.354857   34.857143    0
# 3     0.123200   88.667630  0.372030   34.851852    0
# 4     0.098543  122.835857  0.482286   43.000000    5

# %% [markdown]
# <h2> Dimensionality Reduction </h2>

# %%
''' PCA - Music data'''

X = data[['danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'duration_ms', 'popularity']]

pca_pipeline = Pipeline([('scaler', StandardScaler()), ('PCA', PCA(n_components = 2))])
X_embedded_pca = pca_pipeline.fit_transform(X)

temp_df = pd.DataFrame()
temp_df['x'] = X_embedded_pca[:, 0]
temp_df['y'] = X_embedded_pca[:, 1]
temp_df.to_csv('drive/MyDrive/USML/v2/pca_music.csv')

# %%
''' tSNE - Music data '''

X = data[['danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'duration_ms', 'popularity']]

tsne_pipeline = Pipeline([('scaler', StandardScaler()), ('tsne', TSNE(n_components = 2, verbose = 1))])
X_embedded_tsne = tsne_pipeline.fit_transform(X)

temp_df = pd.DataFrame()
temp_df['x'] = X_embedded_tsne[:, 0]
temp_df['y'] = X_embedded_tsne[:, 1]
temp_df.to_csv('drive/MyDrive/USML/v2/tsne_music.csv')
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 170653 samples in 0.733s...
# [t-SNE] Computed neighbors for 170653 samples in 743.705s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 170653
# [t-SNE] Computed conditional probabilities for sample 2000 / 170653
# [t-SNE] Computed conditional probabilities for sample 3000 / 170653
# [t-SNE] Computed conditional probabilities for sample 4000 / 170653
# [t-SNE] Computed conditional probabilities for sample 5000 / 170653
# [t-SNE] Computed conditional probabilities for sample 6000 / 170653
# [t-SNE] Computed conditional probabilities for sample 7000 / 170653
# [t-SNE] Computed conditional probabilities for sample 8000 / 170653
# [t-SNE] Computed conditional probabilities for sample 9000 / 170653
# [t-SNE] Computed conditional probabilities for sample 10000 / 170653
# [t-SNE] Computed conditional probabilities for sample 11000 / 170653
# [t-SNE] Computed conditional probabilities for sample 12000 / 170653
# [t-SNE] Computed conditional probabilities for sample 13000 / 170653
# [t-SNE] Computed conditional probabilities for sample 14000 / 170653
# [t-SNE] Computed conditional probabilities for sample 15000 / 170653
# [t-SNE] Computed conditional probabilities for sample 16000 / 170653
# [t-SNE] Computed conditional probabilities for sample 17000 / 170653
# [t-SNE] Computed conditional probabilities for sample 18000 / 170653
# [t-SNE] Computed conditional probabilities for sample 19000 / 170653
# [t-SNE] Computed conditional probabilities for sample 20000 / 170653
# [t-SNE] Computed conditional probabilities for sample 21000 / 170653
# [t-SNE] Computed conditional probabilities for sample 22000 / 170653
# [t-SNE] Computed conditional probabilities for sample 23000 / 170653
# [t-SNE] Computed conditional probabilities for sample 24000 / 170653
# [t-SNE] Computed conditional probabilities for sample 25000 / 170653
# [t-SNE] Computed conditional probabilities for sample 26000 / 170653
# [t-SNE] Computed conditional probabilities for sample 27000 / 170653
# [t-SNE] Computed conditional probabilities for sample 28000 / 170653
# [t-SNE] Computed conditional probabilities for sample 29000 / 170653
# [t-SNE] Computed conditional probabilities for sample 30000 / 170653
# [t-SNE] Computed conditional probabilities for sample 31000 / 170653
# [t-SNE] Computed conditional probabilities for sample 32000 / 170653
# [t-SNE] Computed conditional probabilities for sample 33000 / 170653
# [t-SNE] Computed conditional probabilities for sample 34000 / 170653
# [t-SNE] Computed conditional probabilities for sample 35000 / 170653
# [t-SNE] Computed conditional probabilities for sample 36000 / 170653
# [t-SNE] Computed conditional probabilities for sample 37000 / 170653
# [t-SNE] Computed conditional probabilities for sample 38000 / 170653
# [t-SNE] Computed conditional probabilities for sample 39000 / 170653
# [t-SNE] Computed conditional probabilities for sample 40000 / 170653
# [t-SNE] Computed conditional probabilities for sample 41000 / 170653
# [t-SNE] Computed conditional probabilities for sample 42000 / 170653
# [t-SNE] Computed conditional probabilities for sample 43000 / 170653
# [t-SNE] Computed conditional probabilities for sample 44000 / 170653
# [t-SNE] Computed conditional probabilities for sample 45000 / 170653
# [t-SNE] Computed conditional probabilities for sample 46000 / 170653
# [t-SNE] Computed conditional probabilities for sample 47000 / 170653
# [t-SNE] Computed conditional probabilities for sample 48000 / 170653
# [t-SNE] Computed conditional probabilities for sample 49000 / 170653
# [t-SNE] Computed conditional probabilities for sample 50000 / 170653
# [t-SNE] Computed conditional probabilities for sample 51000 / 170653
# [t-SNE] Computed conditional probabilities for sample 52000 / 170653
# [t-SNE] Computed conditional probabilities for sample 53000 / 170653
# [t-SNE] Computed conditional probabilities for sample 54000 / 170653
# [t-SNE] Computed conditional probabilities for sample 55000 / 170653
# [t-SNE] Computed conditional probabilities for sample 56000 / 170653
# [t-SNE] Computed conditional probabilities for sample 57000 / 170653
# [t-SNE] Computed conditional probabilities for sample 58000 / 170653
# [t-SNE] Computed conditional probabilities for sample 59000 / 170653
# [t-SNE] Computed conditional probabilities for sample 60000 / 170653
# [t-SNE] Computed conditional probabilities for sample 61000 / 170653
# [t-SNE] Computed conditional probabilities for sample 62000 / 170653
# [t-SNE] Computed conditional probabilities for sample 63000 / 170653
# [t-SNE] Computed conditional probabilities for sample 64000 / 170653
# [t-SNE] Computed conditional probabilities for sample 65000 / 170653
# [t-SNE] Computed conditional probabilities for sample 66000 / 170653
# [t-SNE] Computed conditional probabilities for sample 67000 / 170653
# [t-SNE] Computed conditional probabilities for sample 68000 / 170653
# [t-SNE] Computed conditional probabilities for sample 69000 / 170653
# [t-SNE] Computed conditional probabilities for sample 70000 / 170653
# [t-SNE] Computed conditional probabilities for sample 71000 / 170653
# [t-SNE] Computed conditional probabilities for sample 72000 / 170653
# [t-SNE] Computed conditional probabilities for sample 73000 / 170653
# [t-SNE] Computed conditional probabilities for sample 74000 / 170653
# [t-SNE] Computed conditional probabilities for sample 75000 / 170653
# [t-SNE] Computed conditional probabilities for sample 76000 / 170653
# [t-SNE] Computed conditional probabilities for sample 77000 / 170653
# [t-SNE] Computed conditional probabilities for sample 78000 / 170653
# [t-SNE] Computed conditional probabilities for sample 79000 / 170653
# [t-SNE] Computed conditional probabilities for sample 80000 / 170653
# [t-SNE] Computed conditional probabilities for sample 81000 / 170653
# [t-SNE] Computed conditional probabilities for sample 82000 / 170653
# [t-SNE] Computed conditional probabilities for sample 83000 / 170653
# [t-SNE] Computed conditional probabilities for sample 84000 / 170653
# [t-SNE] Computed conditional probabilities for sample 85000 / 170653
# [t-SNE] Computed conditional probabilities for sample 86000 / 170653
# [t-SNE] Computed conditional probabilities for sample 87000 / 170653
# [t-SNE] Computed conditional probabilities for sample 88000 / 170653
# [t-SNE] Computed conditional probabilities for sample 89000 / 170653
# [t-SNE] Computed conditional probabilities for sample 90000 / 170653
# [t-SNE] Computed conditional probabilities for sample 91000 / 170653
# [t-SNE] Computed conditional probabilities for sample 92000 / 170653
# [t-SNE] Computed conditional probabilities for sample 93000 / 170653
# [t-SNE] Computed conditional probabilities for sample 94000 / 170653
# [t-SNE] Computed conditional probabilities for sample 95000 / 170653
# [t-SNE] Computed conditional probabilities for sample 96000 / 170653
# [t-SNE] Computed conditional probabilities for sample 97000 / 170653
# [t-SNE] Computed conditional probabilities for sample 98000 / 170653
# [t-SNE] Computed conditional probabilities for sample 99000 / 170653
# [t-SNE] Computed conditional probabilities for sample 100000 / 170653
# [t-SNE] Computed conditional probabilities for sample 101000 / 170653
# [t-SNE] Computed conditional probabilities for sample 102000 / 170653
# [t-SNE] Computed conditional probabilities for sample 103000 / 170653
# [t-SNE] Computed conditional probabilities for sample 104000 / 170653
# [t-SNE] Computed conditional probabilities for sample 105000 / 170653
# [t-SNE] Computed conditional probabilities for sample 106000 / 170653
# [t-SNE] Computed conditional probabilities for sample 107000 / 170653
# [t-SNE] Computed conditional probabilities for sample 108000 / 170653
# [t-SNE] Computed conditional probabilities for sample 109000 / 170653
# [t-SNE] Computed conditional probabilities for sample 110000 / 170653
# [t-SNE] Computed conditional probabilities for sample 111000 / 170653
# [t-SNE] Computed conditional probabilities for sample 112000 / 170653
# [t-SNE] Computed conditional probabilities for sample 113000 / 170653
# [t-SNE] Computed conditional probabilities for sample 114000 / 170653
# [t-SNE] Computed conditional probabilities for sample 115000 / 170653
# [t-SNE] Computed conditional probabilities for sample 116000 / 170653
# [t-SNE] Computed conditional probabilities for sample 117000 / 170653
# [t-SNE] Computed conditional probabilities for sample 118000 / 170653
# [t-SNE] Computed conditional probabilities for sample 119000 / 170653
# [t-SNE] Computed conditional probabilities for sample 120000 / 170653
# [t-SNE] Computed conditional probabilities for sample 121000 / 170653
# [t-SNE] Computed conditional probabilities for sample 122000 / 170653
# [t-SNE] Computed conditional probabilities for sample 123000 / 170653
# [t-SNE] Computed conditional probabilities for sample 124000 / 170653
# [t-SNE] Computed conditional probabilities for sample 125000 / 170653
# [t-SNE] Computed conditional probabilities for sample 126000 / 170653
# [t-SNE] Computed conditional probabilities for sample 127000 / 170653
# [t-SNE] Computed conditional probabilities for sample 128000 / 170653
# [t-SNE] Computed conditional probabilities for sample 129000 / 170653
# [t-SNE] Computed conditional probabilities for sample 130000 / 170653
# [t-SNE] Computed conditional probabilities for sample 131000 / 170653
# [t-SNE] Computed conditional probabilities for sample 132000 / 170653
# [t-SNE] Computed conditional probabilities for sample 133000 / 170653
# [t-SNE] Computed conditional probabilities for sample 134000 / 170653
# [t-SNE] Computed conditional probabilities for sample 135000 / 170653
# [t-SNE] Computed conditional probabilities for sample 136000 / 170653
# [t-SNE] Computed conditional probabilities for sample 137000 / 170653
# [t-SNE] Computed conditional probabilities for sample 138000 / 170653
# [t-SNE] Computed conditional probabilities for sample 139000 / 170653
# [t-SNE] Computed conditional probabilities for sample 140000 / 170653
# [t-SNE] Computed conditional probabilities for sample 141000 / 170653
# [t-SNE] Computed conditional probabilities for sample 142000 / 170653
# [t-SNE] Computed conditional probabilities for sample 143000 / 170653
# [t-SNE] Computed conditional probabilities for sample 144000 / 170653
# [t-SNE] Computed conditional probabilities for sample 145000 / 170653
# [t-SNE] Computed conditional probabilities for sample 146000 / 170653
# [t-SNE] Computed conditional probabilities for sample 147000 / 170653
# [t-SNE] Computed conditional probabilities for sample 148000 / 170653
# [t-SNE] Computed conditional probabilities for sample 149000 / 170653
# [t-SNE] Computed conditional probabilities for sample 150000 / 170653
# [t-SNE] Computed conditional probabilities for sample 151000 / 170653
# [t-SNE] Computed conditional probabilities for sample 152000 / 170653
# [t-SNE] Computed conditional probabilities for sample 153000 / 170653
# [t-SNE] Computed conditional probabilities for sample 154000 / 170653
# [t-SNE] Computed conditional probabilities for sample 155000 / 170653
# [t-SNE] Computed conditional probabilities for sample 156000 / 170653
# [t-SNE] Computed conditional probabilities for sample 157000 / 170653
# [t-SNE] Computed conditional probabilities for sample 158000 / 170653
# [t-SNE] Computed conditional probabilities for sample 159000 / 170653
# [t-SNE] Computed conditional probabilities for sample 160000 / 170653
# [t-SNE] Computed conditional probabilities for sample 161000 / 170653
# [t-SNE] Computed conditional probabilities for sample 162000 / 170653
# [t-SNE] Computed conditional probabilities for sample 163000 / 170653
# [t-SNE] Computed conditional probabilities for sample 164000 / 170653
# [t-SNE] Computed conditional probabilities for sample 165000 / 170653
# [t-SNE] Computed conditional probabilities for sample 166000 / 170653
# [t-SNE] Computed conditional probabilities for sample 167000 / 170653
# [t-SNE] Computed conditional probabilities for sample 168000 / 170653
# [t-SNE] Computed conditional probabilities for sample 169000 / 170653
# [t-SNE] Computed conditional probabilities for sample 170000 / 170653
# [t-SNE] Computed conditional probabilities for sample 170653 / 170653
# [t-SNE] Mean sigma: 0.510532
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 127.068123
# [t-SNE] KL divergence after 1000 iterations: 4.271441

# %%
''' PCA - Genre data'''

X = genre_data[['danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'duration_ms', 'popularity']]

pca_pipeline = Pipeline([('scaler', StandardScaler()), ('PCA', PCA(n_components = 2))])
X_embedded_pca = pca_pipeline.fit_transform(X)

temp_df = pd.DataFrame()
temp_df['x'] = X_embedded_pca[:, 0]
temp_df['y'] = X_embedded_pca[:, 1]
temp_df.to_csv('drive/MyDrive/USML/v2/pca_genre.csv')

# %%
''' tSNE - Genre data '''

X = genre_data[['danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'duration_ms', 'popularity']]

tsne_pipeline = Pipeline([('scaler', StandardScaler()), ('tsne', TSNE(n_components = 2, verbose = 1))])
X_embedded_tsne = tsne_pipeline.fit_transform(X)

temp_df = pd.DataFrame()
temp_df['x'] = X_embedded_tsne[:, 0]
temp_df['y'] = X_embedded_tsne[:, 1]
temp_df.to_csv('drive/MyDrive/USML/v2/tsne_genre.csv')

# %%
''' PCA - Artist data'''

X = artist_data[['danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'duration_ms', 'popularity']]

pca_pipeline = Pipeline([('scaler', StandardScaler()), ('PCA', PCA(n_components = 2))])
X_embedded_pca = pca_pipeline.fit_transform(X)

temp_df = pd.DataFrame()
temp_df['x'] = X_embedded_pca[:, 0]
temp_df['y'] = X_embedded_pca[:, 1]
temp_df.to_csv('drive/MyDrive/USML/v2/pca_artist.csv')

# %%
''' tSNE - Artist data '''

X = artist_data[['danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'duration_ms']]

tsne_pipeline = Pipeline([('scaler', StandardScaler()), ('tsne', TSNE(n_components = 2, verbose = 1))])
X_embedded_tsne = tsne_pipeline.fit_transform(X)

temp_df = pd.DataFrame()
temp_df['x'] = X_embedded_tsne[:, 0]
temp_df['y'] = X_embedded_tsne[:, 1]
temp_df.to_csv('drive/MyDrive/USML/v2/tsne_artist.csv')
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 28680 samples in 0.058s...
# [t-SNE] Computed neighbors for 28680 samples in 16.295s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 28680
# [t-SNE] Computed conditional probabilities for sample 2000 / 28680
# [t-SNE] Computed conditional probabilities for sample 3000 / 28680
# [t-SNE] Computed conditional probabilities for sample 4000 / 28680
# [t-SNE] Computed conditional probabilities for sample 5000 / 28680
# [t-SNE] Computed conditional probabilities for sample 6000 / 28680
# [t-SNE] Computed conditional probabilities for sample 7000 / 28680
# [t-SNE] Computed conditional probabilities for sample 8000 / 28680
# [t-SNE] Computed conditional probabilities for sample 9000 / 28680
# [t-SNE] Computed conditional probabilities for sample 10000 / 28680
# [t-SNE] Computed conditional probabilities for sample 11000 / 28680
# [t-SNE] Computed conditional probabilities for sample 12000 / 28680
# [t-SNE] Computed conditional probabilities for sample 13000 / 28680
# [t-SNE] Computed conditional probabilities for sample 14000 / 28680
# [t-SNE] Computed conditional probabilities for sample 15000 / 28680
# [t-SNE] Computed conditional probabilities for sample 16000 / 28680
# [t-SNE] Computed conditional probabilities for sample 17000 / 28680
# [t-SNE] Computed conditional probabilities for sample 18000 / 28680
# [t-SNE] Computed conditional probabilities for sample 19000 / 28680
# [t-SNE] Computed conditional probabilities for sample 20000 / 28680
# [t-SNE] Computed conditional probabilities for sample 21000 / 28680
# [t-SNE] Computed conditional probabilities for sample 22000 / 28680
# [t-SNE] Computed conditional probabilities for sample 23000 / 28680
# [t-SNE] Computed conditional probabilities for sample 24000 / 28680
# [t-SNE] Computed conditional probabilities for sample 25000 / 28680
# [t-SNE] Computed conditional probabilities for sample 26000 / 28680
# [t-SNE] Computed conditional probabilities for sample 27000 / 28680
# [t-SNE] Computed conditional probabilities for sample 28000 / 28680
# [t-SNE] Computed conditional probabilities for sample 28680 / 28680
# [t-SNE] Mean sigma: 0.580481
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 96.652512
# [t-SNE] KL divergence after 1000 iterations: 2.579452

# %%
''' Read PCA and tSNE embeddings '''

pca_music = pd.read_csv('drive/MyDrive/USML/v2/pca_music.csv')
tsne_music = pd.read_csv('drive/MyDrive/USML/v2/tsne_music.csv')

# %%
pca.head()
# Out:
#    Unnamed: 0         x         y
# 0           0  3.810762  3.237547
# 1           1 -0.287322 -3.140135
# 2           2  3.306169  1.978608
# 3           3  1.503984  1.011282
# 4           4  1.439878  0.103652

# %%
tsne.head()
# Out:
#    Unnamed: 0         x         y
# 0           0  3.810762  3.237547
# 1           1 -0.287322 -3.140135
# 2           2  3.306169  1.978608
# 3           3  1.503984  1.011282
# 4           4  1.439878  0.103652
